# %%
from Levenshtein import distance
import pandas as pd

# %% [markdown]
# |notes | Armbrust | Mask Nerd |
# | - | - | - |
# | - | Close to standard testing at 85 LPM | Using his face to test at normal breathing rates |
# | Filtration Efficiency | Will be a lower bound for typical (non-exercise) usage since it's at 85 LPM | |

# %% [markdown]
# # Armbrust

# %% [markdown]
# ## Load Armbrust data set

# %%
armbrust = pd.read_csv('./data/armbrust-testing-dataset-2024-07-30.csv')

# %%
armbrust
# Out:
#                             unique_internal_model_code  color filter_type  \
# 0    Dr. Puri Stylish Black Micro-Dust Protection Mask  Black        KF94
# 1                       3M 9205+ Aura: User Submission  White         N95
# 2                        HOM KN95 Protective Face Mask  White        KN95
# 3                                   MediMask KF94 Mask  White        KF94
# 4                  Armbrust FFR AA-1976 Cup-Style Mask  White         NaN
# ..                                                 ...    ...         ...
# 625                                    SOOMSHI-GO KF94  Black        KF94
# 626                                   Good Manner KF94  White        KF94
# 627                            Blue KF94 Tiger 3D Mask  White        KF94
# 628                                       PinzTec KN95  White        KN95
# 629                              PURE Environments N95  White         N95
#
#      filtration_efficiency_percent breathability_pascals  \
# ...

# %% [markdown]
# ### Add notes and source info for filtration efficiency and breathability

# %%
armbrust['filtration_efficiency_source'] = 'https://www.armbrustusa.com/pages/mask-testing'
armbrust['filtration_efficiency_notes'] = 'Lloyd from Armbrust used a TSI 8130 PFE testing machine (very accurate and precise at 85 LPM flow rate)'
armbrust['breathability_pascals_source'] = 'https://www.armbrustusa.com/pages/mask-testing'
armbrust['breathability_pascals_notes'] = 'Lloyd from Armbrust used a TSI 8130 PFE testing machine (very accurate and precise at 85 LPM flow rate)'

# %% [markdown]
# ### Add age_range to blank

# %%
armbrust['age_range'] = ''

# %% [markdown]
# ### Add `where_to_buy_url`s as blank

# %%
armbrust['where_to_buy_url_1'] = armbrust['where_to_buy_url'] 
armbrust['where_to_buy_url_2'] = ''
armbrust['where_to_buy_url_3'] = ''

# %% [markdown]
# ### Add width_mm and height_mm columns as blank

# %%
armbrust['width_mm'] = None
armbrust['height_mm'] = None

# %%
armbrust.groupby('test_source').count()
# Out:
#              unique_internal_model_code  color  filter_type  \
# test_source
# Armbrust                            260    259          253
# CDC                                 240    230          233
# undefined                            43     43           35
#
#              filtration_efficiency_percent  breathability_pascals  image_url  \
# test_source
# Armbrust                               260                    260        260
# CDC                                    244                    244        244
# undefined                               43                     43         43
#
#              style  origin  manufacturer  strap_type  ...  \
# test_source                                           ...
# Armbrust       260     260           260         259  ...
# CDC            240     244           244         240  ...
# undefined       43      43            43          43  ...
#
#              filtration_efficiency_source  filtration_efficiency_notes  \
# test_source
# ...

# %%
armbrust.groupby(['test_source', 'origin']).count()
# Out:
#                        unique_internal_model_code  color  filter_type  \
# test_source origin
# Armbrust    China                             141    140          141
#             India                               3      3            3
#             Korea                              59     59           59
#             Mexico                              1      1            1
#             Singapore                           3      3            3
#             USA                                53     53           46
# CDC         China                             215    213          215
#             Europe                              2      2            2
#             Korea                               5      5            5
#             USA                                10     10            8
#             –                                   8      0            3
# undefined   China                              14     14           13
# ...

# %%
armbrust.isna().describe()
# Out:
#        unique_internal_model_code  color filter_type  \
# count                         630    630         630
# unique                          2      2           2
# top                         False  False       False
# freq                          626    613         598
#
#        filtration_efficiency_percent breathability_pascals image_url  style  \
# count                            630                   630       630    630
# unique                             1                     1         1      2
# top                            False                 False     False  False
# freq                             630                   630       630    623
#
#        origin manufacturer strap_type  ... filtration_efficiency_source  \
# count     630          630        630  ...                          630
# unique      1            1          2  ...                            1
# top     False        False      False  ...                        False
# ...

# %% [markdown]
# ### Set Flat-Fold to Bifold

# %%
armbrust.loc[
    armbrust['style'] == 'Flat-Fold', 'style'
] = 'Bifold'

# %% [markdown]
# ## Looks like those that are missing unique_internal_model_codes are also missing image_urls.
#
# Let's just drop these for now.

# %%
armbrust[
    armbrust['unique_internal_model_code'].isna()
]
# Out:
#     unique_internal_model_code color filter_type  \
# 248                        NaN   NaN         NaN
# 249                        NaN   NaN         NaN
# 255                        NaN   NaN         N95
# 256                        NaN   NaN         N95
#
#      filtration_efficiency_percent breathability_pascals  \
# 248                          96.48                   0.0
# 249                          98.48                   0.0
# 255                          99.05                110.82
# 256                          98.24                103.95
#
#                                              image_url   style origin  \
# 248  https://cdn.shopify.com/s/files/1/0384/4145/16...     NaN      –
# 249  https://cdn.shopify.com/s/files/1/0384/4145/16...     NaN      –
# 255  https://cdn.shopify.com/s/files/1/0384/4145/16...  Bifold  China
# 256  https://cdn.shopify.com/s/files/1/0384/4145/16...  Bifold  China
#
#        manufacturer strap_type  ...  \
# ...

# %%
has_mask_name_armbrust = armbrust[
    armbrust['unique_internal_model_code'].notna()
]

has_mask_name_armbrust.isna().describe()
# Out:
#        unique_internal_model_code  color filter_type  \
# count                         626    626         626
# unique                          1      2           2
# top                         False  False       False
# freq                          626    613         596
#
#        filtration_efficiency_percent breathability_pascals image_url  style  \
# count                            626                   626       626    626
# unique                             1                     1         1      2
# top                            False                 False     False  False
# freq                             626                   626       626    621
#
#        origin manufacturer strap_type  ... filtration_efficiency_source  \
# count     626          626        626  ...                          626
# unique      1            1          2  ...                            1
# top     False        False      False  ...                        False
# ...

# %% [markdown]
# ### filter_type is missing

# %% [markdown]
# Those that are missing filter type could be:
# - custom cloth masks (e.g. Paul Hammant's)
# - 3M Aura PFF* masks

# %%
has_mask_name_armbrust[
    has_mask_name_armbrust['filter_type'].isna()
]
# Out:
#                        unique_internal_model_code         color filter_type  \
# 4             Armbrust FFR AA-1976 Cup-Style Mask         White         NaN
# 25         Lutema M95i - 5 Layer Protection Masks         Black         NaN
# 53                               Lutema M95C Mask  Multicolored         NaN
# 72          Lutema M95c Breathable Kids Face Mask          Blue         NaN
# 146                                  Heromed H801         White         NaN
# 147         Honeywell H801 Particulate Respirator         White         NaN
# 190                                        Desavo           NaN         NaN
# 250                                Vitacore Can99         White         NaN
# 294                                 Sanbang 9051A         White         NaN
# 311           Armbrust FFR AA-1976 Cup-Style Mask         White         NaN
# 366                                        Desavo           NaN         NaN
# ...

# %% [markdown]
# ### image_url is missing

# %%
has_mask_name_armbrust[
    has_mask_name_armbrust['image_url'].isna() 
]
# Out:
# Empty DataFrame
# Columns: [unique_internal_model_code, color, filter_type, filtration_efficiency_percent, breathability_pascals, image_url, style, origin, manufacturer, strap_type, test_source, where_to_buy_url, filtration_efficiency_source, filtration_efficiency_notes, breathability_pascals_source, breathability_pascals_notes, age_range, where_to_buy_url_1, where_to_buy_url_2, where_to_buy_url_3, width_mm, height_mm]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ## Filter for unique_internal_model_code, image_url, filter_type

# %% [markdown]
# After filtering for those, the next largest source of missingness is `test_source`.

# %%
has_mask_name_image_url_filter_type_armbrust = armbrust[
    armbrust['unique_internal_model_code'].notna()
    & armbrust['image_url'].notna() 
    & armbrust['filter_type'].notna()
]

has_mask_name_image_url_filter_type_armbrust.isna().describe()
# Out:
#        unique_internal_model_code  color filter_type  \
# count                         596    596         596
# unique                          1      2           1
# top                         False  False       False
# freq                          596    588         596
#
#        filtration_efficiency_percent breathability_pascals image_url  style  \
# count                            596                   596       596    596
# unique                             1                     1         1      2
# top                            False                 False     False  False
# freq                             596                   596       596    593
#
#        origin manufacturer strap_type  ... filtration_efficiency_source  \
# count     596          596        596  ...                          596
# unique      1            1          2  ...                            1
# top     False        False      False  ...                        False
# ...

# %%
has_mask_name_image_url_filter_type_armbrust[
    has_mask_name_image_url_filter_type_armbrust['test_source'].isna()
]
# Out:
#                        unique_internal_model_code  color filter_type  \
# 504       Milwaukee Valved Respirator with Gasket  White         N95
# 505                       SCKOOGH KN95-Mask-01-01  White        KN95
# 506                             3M 8511 Cool Flow  White         N95
# 509            Wanwane White KN95 Disposible Mask  White        KN95
# 510  Aero Armor Three Dimensional Protective Mask  White        KN95
# ..                                            ...    ...         ...
# 582                             Earhook KN95 Mask  White        KN95
# 583                                 Wellcare KN95  White        KN95
# 584                           GreenCare KN95 Mask  Black        KN95
# 585                                      Arx KF94  White        KF94
# 586                                    MB100 KF94  White        KF94
#
#      filtration_efficiency_percent breathability_pascals  \
# 504                          99.70                   155
# ...

# %% [markdown]
# In the list of rows with `null` `test_source`, "Mask Lab Korean Style Respirator" is one of the options. Googling that led me to this [Armbrust review](https://www.armbrustusa.com/blogs/mask-review/kn95-mask-lab-boat-adult-regular-graphics-usub037). Seems like Lloyd tested that himself as well. So not sure what the relevance of the `test_source` being null is. Let's keep null rows.

# %% [markdown]
# ## certainly_high_quality_filters_armbrust

# %% [markdown]
# Filter for at least 95% of particles.

# %%
certainly_high_quality_filters_armbrust = has_mask_name_image_url_filter_type_armbrust[
    has_mask_name_image_url_filter_type_armbrust['filtration_efficiency_percent'] > 95
].copy()

certainly_high_quality_filters_armbrust
# Out:
#                             unique_internal_model_code  color filter_type  \
# 0    Dr. Puri Stylish Black Micro-Dust Protection Mask  Black        KF94
# 1                       3M 9205+ Aura: User Submission  White         N95
# 2                        HOM KN95 Protective Face Mask  White        KN95
# 3                                   MediMask KF94 Mask  White        KF94
# 5        Demetech N95 Respirator DT-N95-CH - Cup Style  White         N95
# ..                                                 ...    ...         ...
# 625                                    SOOMSHI-GO KF94  Black        KF94
# 626                                   Good Manner KF94  White        KF94
# 627                            Blue KF94 Tiger 3D Mask  White        KF94
# 628                                       PinzTec KN95  White        KN95
# 629                              PURE Environments N95  White         N95
#
#      filtration_efficiency_percent breathability_pascals  \
# ...

# %% [markdown]
# ## certainly_high_quality_filters_armbrust_no_surgical

# %%
certainly_high_quality_filters_armbrust_no_surgical = certainly_high_quality_filters_armbrust[
    certainly_high_quality_filters_armbrust['filter_type'] != 'Surgical'
]

# %% [markdown]
# # MaskNerd

# %% [markdown]
# ## MaskNerd for Kids data set

# %%
mask_nerd_kids = pd.read_csv("./data/Kid's Mask Summary[WIP] - Sheet1.csv", header=[12]).rename(
    columns={
        'Mask': 'unique_internal_model_code',
        'Age Range*': 'age_range',
        'Filtration\n Effeciency**': 'filtration_efficiency_percent_str',
        'Pressure Drop\n[Pa]\n***': 'breathability_pascals',
        'Width\n[mm]': 'width_mm',
        'Height\n[mm]': 'height_mm',
        'Source 1': 'where_to_buy_url_1',
        'Source 2': 'where_to_buy_url_2',
        'Source 3': 'where_to_buy_url_3',
    })

# %%
mask_nerd_kids['filtration_efficiency_percent'] = mask_nerd_kids['filtration_efficiency_percent_str'].str.extract('(\d+.\d+)').astype('float')

# %% [markdown]
# ### Split Certification/Style into two columns

# %%
mask_nerd_kids['filter_type'] = mask_nerd_kids['Certification/Style'].str.split('/', expand=True)[0]
mask_nerd_kids['style'] = mask_nerd_kids['Certification/Style'].str.split('/', expand=True)[1]

# %% [markdown]
# ### add filtration_efficiency_source and filtration_efficiency_notes, breathability_pascals_source, breathability_pascals_notes

# %%
mask_nerd_kids['filtration_efficiency_source'] = 'https://docs.google.com/spreadsheets/d/1i06OAItoOwIUaMjElr8mhh0Rw-it6WL-ODIQMZUOQxE/edit?gid=0#gid=0'
mask_nerd_kids['filtration_efficiency_notes'] = 'Aaron Collins (MaskNerd) used his own face, and breathed at his normal adult breathing rate.'
mask_nerd_kids['breathability_pascals_source'] = 'https://docs.google.com/spreadsheets/d/1i06OAItoOwIUaMjElr8mhh0Rw-it6WL-ODIQMZUOQxE/edit?gid=0#gid=0'
mask_nerd_kids['breathability_pascals_notes'] = 'Aaron Collins (MaskNerd) used his own face, and breathed at his normal adult breathing rate.'

# %% [markdown]
# ### add image_url as blank

# %%
mask_nerd_image_url_df = pd.DataFrame([
    {
        'unique_internal_model_code': f'CocoMong XXS Toddler Mask\n[Note this is almost identical in size to U&I Bio, but has printing]',
        'image_url': 'https://m.media-amazon.com/images/I/71d1Rf482CL._AC_SX679_.jpg'
    },
    {
        'unique_internal_model_code': 'The Bio U&I Toddler Mask',
        'image_url': "https://www.protectly.co/cdn/shop/files/Ui1_1296x1296@2x.webp?v=1690348314"
    },
    {
        'unique_internal_model_code': 'HappyLife Gooday Kids Mask - XSmall',
        'image_url': 'https://kollecteusa.com/cdn/shop/products/MainimageBlackMask_GreenPackage_1494x1494.jpg?v=1627764165'
    },
    {
        'unique_internal_model_code': 'Wellbefore Kids KN95 Petite X-Small',
        'image_url': 'https://wellbefore.com/cdn/shop/files/6545099980929_2F000_3D_3D_3D_23color_white_570x.webp?v=1706822496'
    },
    {
        'unique_internal_model_code': 'SaveWo 3D Mask - Kids Small',
        'image_url': 'https://www.family-masks.com/cdn/shop/products/3DMEOW-KIDS-S-MASK3_1024x1024@2x.jpg?v=1679810184'
    },
    {
        'unique_internal_model_code': 'ProductLabs KF94 - Kids',
        'image_url': 'https://kollecteusa.com/cdn/shop/products/KakaoTalk_Image_2022-05-26-09-49-07_1494x1494.jpg?v=1653583943'
    },
    {
        'unique_internal_model_code': 'Posh KF94 Kids Mask',
        'image_url': 'https://behealthyusa.net/cdn/shop/products/POSH_KIDS_KA01.jpg?v=1627409574'
    },
    {
        'unique_internal_model_code': "Kim Well's Kids Mask",
        'image_url': 'https://www.everydayemall.com/cdn/shop/products/KIMSWEL_1080x.png?v=1631151967',
    },
    {
        'unique_internal_model_code': 'Blue Tiger Kids Mask',
        'image_url': 'https://behealthyusa.net/cdn/shop/products/BLUE_TIGER_3D_S_WHITE_KF94.jpg?v=1715614244'
    },
    {
        'unique_internal_model_code': 'Bluna Kids Mask',
        'image_url': 'https://kollecteusa.com/cdn/shop/products/Mainimage_14_64fac663-9908-41be-aa9c-c6aec297cd76_1494x1494.jpg?v=1613714234'
    },
    {
        'unique_internal_model_code': 'BOTN Kids Mask',
        'image_url': 'https://m.media-amazon.com/images/I/71BjC-CqwYL._AC_SX679_.jpg'
    },
    {
        'unique_internal_model_code': 'BreatheTeq - XS',
        'image_url': 'https://breatheteq.com/cdn/shop/products/ChildblackbreatheTeqKN95Canadianmask.jpg?v=1668715763'
    },
    {
        'unique_internal_model_code': 'Happylife Goodday Adj. Earloop Mask',
        'image_url': 'https://kollecteusa.com/cdn/shop/products/GoodDayMainimageBlack_1494x1494.jpg?v=1643666756'
    },
    {
        'unique_internal_model_code': 'Savewo 3D Mask - Kids Large',
        'image_url': 'https://www.family-masks.com/cdn/shop/products/3DMask-Kids-Large-White-Model1_1024x1024@2x.jpg?v=1659191665'
    },
    {
        'unique_internal_model_code': 'Dr. Puri - Small',
        'image_url': 'https://m.media-amazon.com/images/I/61gNyHRaJ-L._AC_SX679_.jpg'
    },
    {
        'unique_internal_model_code': 'Wellbefore Kids KN95 Petite Small',
        'image_url': 'https://wellbefore.com/cdn/shop/files/6545099980929_2F000_3D_3D_3D_23color_white_570x.webp?v=1706822496'
    },
    {
        'unique_internal_model_code': 'Vitacore CAN99e - Kids',
        'image_url': 'https://shop.vitacore.com/cdn/shop/products/CAN99e_Children_10_Box_Mask-min_a48e3100-8340-4fe1-8d7d-c7f45cdcd8ec_1218x816.png?v=1675984335'
    },
    {
        'unique_internal_model_code': 'Birdy Friends Kids Mask',
        'image_url': 'https://www.yesmask.net/wp-content/uploads/2021/01/Zelda-copy.jpg'
    },
    {
        'unique_internal_model_code': 'Blue 2D KF94 Kids Mask',
        'image_url': 'https://behealthyusa.net/cdn/shop/products/BLUE_2D_S_BK_KF94_01.jpg?v=1643087217'
    },
    {
        'unique_internal_model_code': 'Armbrust Kids KN95[US Made]',
        'image_url': 'https://www.armbrustusa.com/cdn/shop/files/pediatrickn95_blue_1000x.webp?v=1718400356'
    },
    {
        'unique_internal_model_code': 'United States Mask Company KidsN95[Head Straps]',
        'image_url': 'https://www.unitedstatesmask.com/cdn/shop/products/3_97c020a3-38b0-465f-bcd7-8eb1f4c86237.png?v=1639514002&width=1206'
    },
    {
        'unique_internal_model_code': 'Powecom KN95-SM',
        'image_url': 'https://cdn11.bigcommerce.com/s-36umx6hkc1/images/stencil/960w/products/255/601/masks_SM_size-04__24269.1667404150.jpg?c=2'
    },
    {
        'unique_internal_model_code': f'GoodDay Happy Life - Youth Size White/Black\nGoodDay Happy Life - Size Small Cartoon Package[SAME MASK]',
        'image_url': 'https://kollecteusa.com/cdn/shop/products/MainimageBlackMask_GreenPackage_1494x1494.jpg?v=1627764165'
    },
    {
        'unique_internal_model_code': 'Cleantop Evergreen KF94 Small - White/Black',
        'image_url': 'https://kollecteusa.com/cdn/shop/products/MainImage_ea9e27e5-322d-456d-a8a5-20e9fe59079c_1494x1494.jpg?v=1629003395'
    },
    {
        'unique_internal_model_code': '4CAir Kids Mask',
        'image_url': 'https://4cair.com/wp-content/uploads/2021/03/BreSafe-Nano-Mask-Kids.png'
    },
    {
        'unique_internal_model_code': 'ETIQA Basic Black - Small',
        'image_url': 'https://behealthyusa.net/cdn/shop/products/1703328368_ab34d4d6-e855-4b30-8340-d6e3df75ba10.jpg?v=1613074520'
    },
    {
        'unique_internal_model_code': 'ETIQA Airlight Round Kids',
        'image_url': 'https://m.media-amazon.com/images/I/31petzbetkL._AC_.jpg'
    },
    {
        'unique_internal_model_code': 'AER Standard Fit, Small',
        'image_url': 'https://flexmonusa.com/cdn/shop/products/Aer_Black_shopify_1-1__M_size_fb76164c-cdb7-4941-b91b-6b468540c21a_1024x1024@2x.jpg?v=1623788479'
    },
    {
        'unique_internal_model_code': 'ETIQA Airlight Round Kids',
        'image_url': 'https://m.media-amazon.com/images/I/31petzbetkL._AC_.jpg'
    },
    {
        'unique_internal_model_code': 'BreatheTeq - Small',
        'image_url': 'https://breatheteq.com/cdn/shop/products/Ash_Grey_CoffeeShop.jpg?v=1668367840'
    },
    {
        'unique_internal_model_code': f'Savewo Ultra 3D - Adult Small\n[also includes Hana Small]',
        'image_url': 'https://www.family-masks.com/cdn/shop/products/Ultra-Small-White-Mask3_1024x1024@2x.jpg?v=1659195917'
    },
    {
        'unique_internal_model_code': 'Lutema M95C/Vida/LittleLivesPPE Mask',
        'image_url': 'https://lutema.com/cdn/shop/products/Image001_1_e1023803-4e9c-4601-95a1-aa41f1108c55_1024x1024@2x.jpg?v=1604775663'
    },
    {
        'unique_internal_model_code': 'Wellbefore Kids KN95 Petite Regular',
        'image_url': 'https://wellbefore.com/cdn/shop/files/6545099980929_2F000_3D_3D_3D_23color_white_570x.webp?v=1706822496'
    },
    {
        'unique_internal_model_code': 'Dobu 500 NIOSH N95',
        'image_url': 'https://m.media-amazon.com/images/I/5178EkU0oNL._AC_CR0%2C0%2C0%2C0_SX960_SY720_.jpg'
    },
])

# %%
mask_nerd_kids.columns
# Out:
# Index(['unique_internal_model_code', 'age_range', 'Certification/Style',
#        'Adj.\n Earloops', 'filtration_efficiency_percent_str',
#        'breathability_pascals', 'width_mm', 'height_mm', 'A\n[mm]', 'B\n[mm]',
#        'C\n[mm]', 'D\n[mm]', 'Sample Image\n on 5.5yr old',
#        'where_to_buy_url_1', 'where_to_buy_url_2', 'where_to_buy_url_3',
#        'Unnamed: 16', 'filtration_efficiency_percent', 'filter_type', 'style',
#        'filtration_efficiency_source', 'filtration_efficiency_notes',
#        'breathability_pascals_source', 'breathability_pascals_notes'],
#       dtype='object')

# %%
mask_nerd_kids = mask_nerd_kids.merge(mask_nerd_image_url_df, on='unique_internal_model_code')
mask_nerd_kids
# Out:
#                            unique_internal_model_code age_range  \
# 0   CocoMong XXS Toddler Mask\n[Note this is almos...       2-5
# 1                            The Bio U&I Toddler Mask       2-5
# 2                 HappyLife Gooday Kids Mask - XSmall     3.5-6
# 3                 Wellbefore Kids KN95 Petite X-Small       2-4
# 4                         SaveWo 3D Mask - Kids Small     3.5-8
# 5                             ProductLabs KF94 - Kids       4-9
# 6                                 Posh KF94 Kids Mask       4-9
# 7                                Kim Well's Kids Mask       4-9
# 8                                Blue Tiger Kids Mask       4-9
# 9                                     Bluna Kids Mask       4-9
# 10                                     BOTN Kids Mask       5-9
# 11                                    BreatheTeq - XS       5-9
# 12                Happylife Goodday Adj. Earloop Mask       5-9
# 13                        Savewo 3D Mask - Kids Large       5-9
# ...

# %%
mask_nerd_kids.columns
# Out:
# Index(['unique_internal_model_code', 'age_range', 'Certification/Style',
#        'Adj.\n Earloops', 'filtration_efficiency_percent_str',
#        'breathability_pascals', 'width_mm', 'height_mm', 'A\n[mm]', 'B\n[mm]',
#        'C\n[mm]', 'D\n[mm]', 'Sample Image\n on 5.5yr old',
#        'where_to_buy_url_1', 'where_to_buy_url_2', 'where_to_buy_url_3',
#        'Unnamed: 16', 'filtration_efficiency_percent', 'filter_type', 'style',
#        'filtration_efficiency_source', 'filtration_efficiency_notes',
#        'breathability_pascals_source', 'breathability_pascals_notes',
#        'image_url'],
#       dtype='object')

# %% [markdown]
# ## add color as blank

# %%
mask_nerd_kids['color'] = ''

# %%
mask_nerd_kids.columns
# Out:
# Index(['unique_internal_model_code', 'age_range', 'Certification/Style',
#        'Adj.\n Earloops', 'filtration_efficiency_percent_str',
#        'breathability_pascals', 'width_mm', 'height_mm', 'A\n[mm]', 'B\n[mm]',
#        'C\n[mm]', 'D\n[mm]', 'Sample Image\n on 5.5yr old',
#        'where_to_buy_url_1', 'where_to_buy_url_2', 'where_to_buy_url_3',
#        'Unnamed: 16', 'filtration_efficiency_percent', 'filter_type', 'style',
#        'filtration_efficiency_source', 'filtration_efficiency_notes',
#        'breathability_pascals_source', 'breathability_pascals_notes',
#        'image_url', 'color'],
#       dtype='object')

# %%
mask_nerd_kids.columns
# Out:
# Index(['unique_internal_model_code', 'age_range', 'Certification/Style',
#        'Adj.\n Earloops', 'filtration_efficiency_percent_str',
#        'breathability_pascals', 'width_mm', 'height_mm', 'A\n[mm]', 'B\n[mm]',
#        'C\n[mm]', 'D\n[mm]', 'Sample Image\n on 5.5yr old',
#        'where_to_buy_url_1', 'where_to_buy_url_2', 'where_to_buy_url_3',
#        'Unnamed: 16', 'filtration_efficiency_percent', 'filter_type', 'style',
#        'filtration_efficiency_source', 'filtration_efficiency_notes',
#        'breathability_pascals_source', 'breathability_pascals_notes',
#        'image_url', 'color'],
#       dtype='object')

# %%
certainly_high_quality_filters_armbrust.columns
# Out:
# Index(['unique_internal_model_code', 'color', 'filter_type',
#        'filtration_efficiency_percent', 'breathability_pascals', 'image_url',
#        'style', 'origin', 'manufacturer', 'strap_type', 'test_source',
#        'where_to_buy_url', 'filtration_efficiency_source',
#        'filtration_efficiency_notes', 'breathability_pascals_source',
#        'breathability_pascals_notes', 'age_range', 'where_to_buy_url_1',
#        'where_to_buy_url_2', 'where_to_buy_url_3', 'width_mm', 'height_mm'],
#       dtype='object')

# %% [markdown]
# ### add blank strap_type

# %%
mask_nerd_kids['strap_type'] = ''

# %% [markdown]
# ### Fix style of a particular mask

# %%
mask_nerd_kids.loc[
    mask_nerd_kids['unique_internal_model_code'].str.contains('Savewo Ultra 3D - Adult'), 
    'style'
] = 'Boat'

# %%
mask_nerd_kids.columns
# Out:
# Index(['unique_internal_model_code', 'age_range', 'Certification/Style',
#        'Adj.\n Earloops', 'filtration_efficiency_percent_str',
#        'breathability_pascals', 'width_mm', 'height_mm', 'A\n[mm]', 'B\n[mm]',
#        'C\n[mm]', 'D\n[mm]', 'Sample Image\n on 5.5yr old',
#        'where_to_buy_url_1', 'where_to_buy_url_2', 'where_to_buy_url_3',
#        'Unnamed: 16', 'filtration_efficiency_percent', 'filter_type', 'style',
#        'filtration_efficiency_source', 'filtration_efficiency_notes',
#        'breathability_pascals_source', 'breathability_pascals_notes',
#        'image_url', 'color', 'strap_type'],
#       dtype='object')

# %%
mask_nerd_kids['filter_type']
# Out:
# 0              KF80
# 1              KF94
# 2              KF94
# 3              KN95
# 4         KF94-KN95
# 5              KF94
# 6              KF94
# 7              KF94
# 8              KF94
# 9              KF94
# 10             KF94
# 11             KN95
# 12             KF94
# 13        KF94-KN95
# 14             KF94
# 15             KN95
# 16       ASTM Lvl 3
# 17    KF94[PENDING]
# 18             KF94
# 19             KN95
# 20        Non-Rated
# 21             KN95
# 22             KF94
# 23             KF94
# 24             KN95
# 25             KF94
# 26         Non-Rate
# 27         Non-Rate
# 28             KF94
# 29             KN95
# 30       FFP2 Rated
# 31            KN95?
# 32             KN95
# 33        NIOSH N95
# Name: filter_type, dtype: object

# %%
mask_nerd_kids
# Out:
#                            unique_internal_model_code age_range  \
# 0   CocoMong XXS Toddler Mask\n[Note this is almos...       2-5
# 1                            The Bio U&I Toddler Mask       2-5
# 2                 HappyLife Gooday Kids Mask - XSmall     3.5-6
# 3                 Wellbefore Kids KN95 Petite X-Small       2-4
# 4                         SaveWo 3D Mask - Kids Small     3.5-8
# 5                             ProductLabs KF94 - Kids       4-9
# 6                                 Posh KF94 Kids Mask       4-9
# 7                                Kim Well's Kids Mask       4-9
# 8                                Blue Tiger Kids Mask       4-9
# 9                                     Bluna Kids Mask       4-9
# 10                                     BOTN Kids Mask       5-9
# 11                                    BreatheTeq - XS       5-9
# 12                Happylife Goodday Adj. Earloop Mask       5-9
# 13                        Savewo 3D Mask - Kids Large       5-9
# ...

# %% [markdown]
# ## common_columns

# %%
common_columns = [
    'unique_internal_model_code', 'age_range', 'filtration_efficiency_percent',
       'breathability_pascals', 'width_mm', 'height_mm', 'filter_type', 'style',
        'strap_type', 'color', 'where_to_buy_url_1',
       'where_to_buy_url_2', 'where_to_buy_url_3', 
       'image_url',     
       'filtration_efficiency_source', 'filtration_efficiency_notes',
       'breathability_pascals_source', 'breathability_pascals_notes'
        
]

# %%
mask_nerd_kids[
    common_columns
]
# Out:
#                            unique_internal_model_code age_range  \
# 0   CocoMong XXS Toddler Mask\n[Note this is almos...       2-5
# 1                            The Bio U&I Toddler Mask       2-5
# 2                 HappyLife Gooday Kids Mask - XSmall     3.5-6
# 3                 Wellbefore Kids KN95 Petite X-Small       2-4
# 4                         SaveWo 3D Mask - Kids Small     3.5-8
# 5                             ProductLabs KF94 - Kids       4-9
# 6                                 Posh KF94 Kids Mask       4-9
# 7                                Kim Well's Kids Mask       4-9
# 8                                Blue Tiger Kids Mask       4-9
# 9                                     Bluna Kids Mask       4-9
# 10                                     BOTN Kids Mask       5-9
# 11                                    BreatheTeq - XS       5-9
# 12                Happylife Goodday Adj. Earloop Mask       5-9
# 13                        Savewo 3D Mask - Kids Large       5-9
# ...

# %% [markdown]
# # distances

# %%
def compare_two_columns_across(df_1, df_2, df_1_col, df_2_col, prefixes):
    collection = []
    for i, df_1_row in df_1.iterrows():
        for j, df_2_row in df_2.iterrows():
            try:
                dist = distance(df_1_row[df_1_col], df_2_row[df_2_col])
            except Exception as e:
                import pdb; pdb.set_trace()
            
            data = {
                f'{prefixes[0]}_col': df_1_row[df_1_col],
                f'{prefixes[1]}_col': df_2_row[df_2_col],
                f'{prefixes[0]}_index': i,
                f'{prefixes[1]}_index': j,
                'distance': dist
            }

            collection.append(data)

    return pd.DataFrame(collection)

# %%
mask_name_distances = compare_two_columns_across(
    mask_nerd_kids, 
    certainly_high_quality_filters_armbrust, 
    'unique_internal_model_code',
    'unique_internal_model_code',
    prefixes=('mnk', 'armbrust')
)

# %%
mask_name_distances
# Out:
#                                                  mnk_col  \
# 0      CocoMong XXS Toddler Mask\n[Note this is almos...
# 1      CocoMong XXS Toddler Mask\n[Note this is almos...
# 2      CocoMong XXS Toddler Mask\n[Note this is almos...
# 3      CocoMong XXS Toddler Mask\n[Note this is almos...
# 4      CocoMong XXS Toddler Mask\n[Note this is almos...
# ...                                                  ...
# 20225                                 Dobu 500 NIOSH N95
# 20226                                 Dobu 500 NIOSH N95
# 20227                                 Dobu 500 NIOSH N95
# 20228                                 Dobu 500 NIOSH N95
# 20229                                 Dobu 500 NIOSH N95
#
#                                             armbrust_col  mnk_index  \
# 0      Dr. Puri Stylish Black Micro-Dust Protection Mask          0
# 1                         3M 9205+ Aura: User Submission          0
# 2                          HOM KN95 Protective Face Mask          0
# ...

# %% [markdown]
# ### Looks like there's barely any overlap between the two data sets
#
# Based on Levenshtein distance, Mask Nerd for Kids data set and Armbrust's data set have tiny overlap (e.g. Blue Tiger Kids Mask) and Powecom KN95.

# %%
mask_name_distances[
    mask_name_distances['distance'] < 10
]
# Out:
#                       mnk_col             armbrust_col  mnk_index  \
# 3643      Posh KF94 Kids Mask   AOTDAOU KN95 Kids Mask          6
# 3665      Posh KF94 Kids Mask            EHH KF94 Mask          6
# 5049     Blue Tiger Kids Mask       Purvigor KN95 Mask          8
# 5352     Blue Tiger Kids Mask  Blue KF94 Tiger 3D Mask          8
# 5368          Bluna Kids Mask         Allmed KN95 Mask          9
# 5427          Bluna Kids Mask          Sheal Face Mask          9
# 5442          Bluna Kids Mask          NYBEE KF94 Mask          9
# 5450          Bluna Kids Mask            EHH KF94 Mask          9
# 5654          Bluna Kids Mask         Allmed KN95 Mask          9
# 5679          Bluna Kids Mask          Sheal Face Mask          9
# 5724          Bluna Kids Mask         Allmed KN95 Mask          9
# 5749          Bluna Kids Mask          Sheal Face Mask          9
# 5854          Bluna Kids Mask            BYD KN95 Mask          9
# ...

# %% [markdown]
# # Combine the two data sets

# %%
concat = pd.concat(
    [
        mask_nerd_kids[common_columns],
        certainly_high_quality_filters_armbrust_no_surgical[common_columns]
    ]
)

# %%
concat[concat['filtration_efficiency_percent'] == '–']
# Out:
# Empty DataFrame
# Columns: [unique_internal_model_code, age_range, filtration_efficiency_percent, breathability_pascals, width_mm, height_mm, filter_type, style, strap_type, color, where_to_buy_url_1, where_to_buy_url_2, where_to_buy_url_3, image_url, filtration_efficiency_source, filtration_efficiency_notes, breathability_pascals_source, breathability_pascals_notes]
# Index: []

# %%
import numpy as np

# %%
concat.loc[
    (concat['breathability_pascals'] == '–'),
    'breathability_pascals'
] = np.nan

# %%
concat[concat['breathability_pascals'] == '–']
# Out:
# Empty DataFrame
# Columns: [unique_internal_model_code, age_range, filtration_efficiency_percent, breathability_pascals, width_mm, height_mm, filter_type, style, strap_type, color, where_to_buy_url_1, where_to_buy_url_2, where_to_buy_url_3, image_url, filtration_efficiency_source, filtration_efficiency_notes, breathability_pascals_source, breathability_pascals_notes]
# Index: []

# %%
for col in ['filtration_efficiency_percent', 'breathability_pascals']:
    concat[col] = concat[col].astype(float)

# %%
concat['uimc_lower'] = concat['unique_internal_model_code'].str.lower().str.strip()
concat['uimc_lower']
# Out:
# 0      cocomong xxs toddler mask\n[note this is almos...
# 1                               the bio u&i toddler mask
# 2                    happylife gooday kids mask - xsmall
# 3                    wellbefore kids kn95 petite x-small
# 4                            savewo 3d mask - kids small
#                              ...
# 625                                      soomshi-go kf94
# 626                                     good manner kf94
# 627                              blue kf94 tiger 3d mask
# 628                                         pinztec kn95
# 629                                pure environments n95
# Name: uimc_lower, Length: 629, dtype: object

# %% [markdown]
# ### no_dups_by_uimc_breathability_fe

# %%
no_dups_by_uimc_breathability_fe = concat.drop_duplicates(
    subset=['uimc_lower', 'breathability_pascals', 'filtration_efficiency_percent']
).sort_values(by='uimc_lower')

no_dups_by_uimc_breathability_fe
# Out:
#                             unique_internal_model_code age_range  \
# 129                                         1Med 4LPR1
# 536                                       3D Mask KN95
# 523    3M 1804 VFlex Healthcare Particulate Respirator
# 611                                        3M 1860 N95
# 15     3M 1860 Surgical Respirator N95 - Possible Fake
# ..                                                 ...       ...
# 269  Zhiyi Medical Self-Priming Filter Respirator KN95
# 262                                    Zhong Yi ZYB II
# 236               Zhongyue Health KN95 Protective Mask
# 215      Zhushi Pharmaceutical Medical Protective Mask
# 60     Zovator (Harley) N95 Mask NIOSH N95 TC-84A-6973
#
#      filtration_efficiency_percent  breathability_pascals width_mm height_mm  \
# 129                          96.91                 199.07     None      None
# 536                          99.98                 138.10     None      None
# ...

# %%
no_dups_by_uimc_breathability_fe[
    no_dups_by_uimc_breathability_fe['where_to_buy_url_1'].notna()
]
# Out:
#                           unique_internal_model_code age_range  \
# 415                  3M 9205+ Aura - User Submission
# 1                     3M 9205+ Aura: User Submission
# 102         3M Aura Particulate Respirator 9205+ N95
# 24                                   4CAir Kids Mask      8-12
# 104                      ACI Surgical N95 Respirator
# ..                                               ...       ...
# 27                            Yongjie KN95 Face Mask
# 18                       Yuikio KN95 Protective Mask
# 424                     Yuikio KN95 Protective Masks
# 82                            Zerobay KF94 Face Mask
# 60   Zovator (Harley) N95 Mask NIOSH N95 TC-84A-6973
#
#      filtration_efficiency_percent  breathability_pascals width_mm height_mm  \
# 415                         100.00                 242.44     None      None
# 1                           100.00                 242.44     None      None
# ...

# %%
old_copy = pd.read_csv("./data/2024-07-30-mask-data-set - mask_data_to_import.csv")
old_copy
# Out:
#                             unique_internal_model_code age_range  \
# 0    CocoMong XXS Toddler Mask\n[Note this is almos...       2-5
# 1                             The Bio U&I Toddler Mask       2-5
# 2                  HappyLife Gooday Kids Mask - XSmall     3.5-6
# 3                  Wellbefore Kids KN95 Petite X-Small       2-4
# 4                          SaveWo 3D Mask - Kids Small     3.5-8
# ..                                                 ...       ...
# 642                    Halyard Fluidshield 46827 Small       NaN
# 643                                         Q100 Small       NaN
# 644                                          Trident S       NaN
# 645                               Champak PC520 Medium       NaN
# 646  3M 1804 VFlex Healthcare Particulate Respirato...       NaN
#
#      filtration_efficiency_percent breathability_pascals  width_mm  height_mm  \
# 0                             98.3                   134     148.0       55.0
# ...

# %% [markdown]
# ## image_urls for "ParentMishmash for Kids"

# %%
pmm_masks = pd.DataFrame([
    {
        'unique_internal_model_code': 'Savewo 3D Meow 2-6 years',
        'image_url': 'https://www.family-masks.com/cdn/shop/products/3DMask-Kids-Small-White-Model2_1024x1024@2x.jpg?v=1659191681'

    },
    {
        'unique_internal_model_code': 'Savewo 3D Meow 7-13 years',
        'image_url': 'https://www.family-masks.com/cdn/shop/products/3DMask-Kids-Large-White-Model1_1024x1024@2x.jpg?v=1659191665'
    },
    {
        'unique_internal_model_code': 'Zimi 7711 w/ Earloops, no Exhalation Valve',
        'image_url': 'https://i0.wp.com/ppeo.com/wp-content/uploads/2024/04/ZiMi-Air-Particulate-Respirator-ZM7711-KN95-Masks-jpg.webp?w=600&ssl=1'
    },
    {
        'unique_internal_model_code': 'Zimi 7711 w/ Earloops, Exhalation Valve',
        'image_url': 'https://i0.wp.com/ppeo.com/wp-content/uploads/2024/04/ZM7711-mask-with-valve.jpg?fit=600%2C600&ssl=1'
    },
    {
        'unique_internal_model_code': 'Zimi 7711 w/ Headband, no Exhalation Valve',
        'image_url': 'https://i0.wp.com/ppeo.com/wp-content/uploads/2024/04/ZiMi-Air-Particulate-Respirator-ZM7711-KN95-Masks-jpg.webp?w=600&ssl=1'
    },
    {
        'unique_internal_model_code': 'Zimi 7711 w/ Headband, Exhalation Valve',
        'image_url': 'https://i0.wp.com/ppeo.com/wp-content/uploads/2024/04/ZM7711-mask-with-valve.jpg?fit=600%2C600&ssl=1'
    },
    {
        'unique_internal_model_code': 'Canada Masq Q100 XS',
        'image_url': 'https://canadastrong.ca/cdn/shop/files/CanadaMasqQ100XSKidsearlooprespiratormaskCSACertified2.png?v=1691120714&width=1000'
    },
    {
        'unique_internal_model_code': 'Trident XS',
        'image_url': 'https://hlpmedical.net/cdn/shop/products/unnamed_5964f7aa-83d1-42e8-9761-a1a638519f40.png?v=1688742729&width=990'
    },
    {
        'unique_internal_model_code': 'Vogmask Small',
        'image_url': 'https://www.vogmask.com/cdn/shop/files/organicnaturalVMcopy.jpg?v=1701808417'
    },
    {
        'unique_internal_model_code': 'Vogmask Organic Medium',
        'image_url': 'https://www.vogmask.com/cdn/shop/files/organicnaturalVMcopy.jpg?v=1701808417'
    },
    {
        'unique_internal_model_code': 'Shawmut Protex SR9520S - Small',
        'image_url': 'https://shop.shawmutcorp.com/cdn/shop/products/Protex_N95Respirator_SR9520Swith20pack_USA_ADC_SHOPIFY_1024x1024@2x.png?v=1670515183'
    },
    {
        'unique_internal_model_code': '3M 1860s',
        'image_url': 'https://m.media-amazon.com/images/I/61J5YrH5rTL._SL1500_.jpg'
    },
    {
        'unique_internal_model_code': 'Halyard Fluidshield 46827 Small',
        'image_url': 'https://m.media-amazon.com/images/I/512xGR0w6zL.jpg'
    },
    {
        'unique_internal_model_code': 'Q100 Small',
        'image_url': 'https://static.wixstatic.com/media/ea1586_f2d6ad262a144efc98dce658e91995e5~mv2.png/v1/fill/w_530,h_530,al_c,usm_0.66_1.00_0.01/ea1586_f2d6ad262a144efc98dce658e91995e5~mv2.png'
    },
    {
        'unique_internal_model_code': 'Trident S',
        'image_url': 'https://hlpmedical.net/cdn/shop/products/unnamed_5964f7aa-83d1-42e8-9761-a1a638519f40.png?v=1688742729&width=990'
    },
    {
        'unique_internal_model_code': 'Champak PC520 Medium',
        'image_url': 'https://www.planethalohealth.com/products/champak-flat-fold-pc520m-pc520l-adjustable-n95-masks-m-l-pack-of-15'
    },    
    {
        'unique_internal_model_code': 'https://www.zoro.com/3m-disposable-respirator-s-pk50-1804s/i/G3793004',
        'image_url': 'https://www.zoro.com/static/cms/product/large/Z1xw5ukcpEx_.JPG'
    },
    
])

# %%
old_copy.columns
# Out:
# Index(['unique_internal_model_code', 'age_range',
#        'filtration_efficiency_percent', 'breathability_pascals', 'width_mm',
#        'height_mm', 'filter_type', 'style', 'strap_type', 'color',
#        'where_to_buy_url_1', 'where_to_buy_url_2', 'where_to_buy_url_3',
#        'image_url', 'filtration_efficiency_source',
#        'filtration_efficiency_notes', 'breatheability_pascals_source',
#        'breatheability_pascals_notes'],
#       dtype='object')

# %% [markdown]
# ## Add data that used to be added manually

# %%
old_copy
# Out:
#                             unique_internal_model_code age_range  \
# 0    CocoMong XXS Toddler Mask\n[Note this is almos...       2-5
# 1                             The Bio U&I Toddler Mask       2-5
# 2                  HappyLife Gooday Kids Mask - XSmall     3.5-6
# 3                  Wellbefore Kids KN95 Petite X-Small       2-4
# 4                          SaveWo 3D Mask - Kids Small     3.5-8
# ..                                                 ...       ...
# 642                    Halyard Fluidshield 46827 Small       NaN
# 643                                         Q100 Small       NaN
# 644                                          Trident S       NaN
# 645                               Champak PC520 Medium       NaN
# 646  3M 1804 VFlex Healthcare Particulate Respirato...       NaN
#
#      filtration_efficiency_percent breathability_pascals  width_mm  height_mm  \
# 0                             98.3                   134     148.0       55.0
# ...

# %%
pmm_with_image_urls = old_copy.loc[630:].copy().merge(
    pmm_masks, on='unique_internal_model_code'
).drop(columns=['image_url_x']).rename(columns={'image_url_y': 'image_url'})

pmm_with_image_urls.loc[pmm_with_image_urls['style'] == 'Flat-Fold', 'style'] = 'Bifold'
pmm_with_image_urls.loc[pmm_with_image_urls['style'] == 'Flat-fold & Gasket', 'style'] = 'Bifold & Gasket'
pmm_with_image_urls['uimc_lower'] = pmm_with_image_urls['unique_internal_model_code'].str.lower().str.strip()

# %%
pmm_with_image_urls
# Out:
#                     unique_internal_model_code age_range  \
# 0                     Savewo 3D Meow 2-6 years       2-6
# 1                    Savewo 3D Meow 7-13 years      7-13
# 2      Zimi 7711 w/ Earloops, Exhalation Valve       NaN
# 3   Zimi 7711 w/ Earloops, no Exhalation Valve       NaN
# 4      Zimi 7711 w/ Headband, Exhalation Valve       NaN
# 5   Zimi 7711 w/ Headband, no Exhalation Valve       NaN
# 6                          Canada Masq Q100 XS       NaN
# 7                                   Trident XS       NaN
# 8                                Vogmask Small       NaN
# 9                       Vogmask Organic Medium       NaN
# 10              Shawmut Protex SR9520S - Small       NaN
# 11                                    3M 1860s       NaN
# 12             Halyard Fluidshield 46827 Small       NaN
# 13                                  Q100 Small       NaN
# 14                                   Trident S       NaN
# ...

# %%
no_dups_by_uimc_breathability_fe
# Out:
#                             unique_internal_model_code age_range  \
# 129                                         1Med 4LPR1
# 536                                       3D Mask KN95
# 523    3M 1804 VFlex Healthcare Particulate Respirator
# 611                                        3M 1860 N95
# 15     3M 1860 Surgical Respirator N95 - Possible Fake
# ..                                                 ...       ...
# 269  Zhiyi Medical Self-Priming Filter Respirator KN95
# 262                                    Zhong Yi ZYB II
# 236               Zhongyue Health KN95 Protective Mask
# 215      Zhushi Pharmaceutical Medical Protective Mask
# 60     Zovator (Harley) N95 Mask NIOSH N95 TC-84A-6973
#
#      filtration_efficiency_percent  breathability_pascals width_mm height_mm  \
# 129                          96.91                 199.07     None      None
# 536                          99.98                 138.10     None      None
# ...

# %%
armbrust_mask_nerd_pmm = pd.concat([
    no_dups_by_uimc_breathability_fe,
    pmm_with_image_urls
]).sort_values(by='uimc_lower')
# Out:
# /var/folders/bt/xj2hnl3n477gb3j4wknqb3x80000gn/T/ipykernel_51918/2388250553.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   armbrust_mask_nerd_pmm = pd.concat([

# %%
armbrust_mask_nerd_pmm.to_csv('./data/armbrust_masknerd_pmm_for_kids.csv', index=False)

# %%
armbrust_mask_nerd_pmm
# Out:
#                           unique_internal_model_code age_range  \
# 129                                       1Med 4LPR1
# 536                                     3D Mask KN95
# 523  3M 1804 VFlex Healthcare Particulate Respirator
# 611                                      3M 1860 N95
# 15   3M 1860 Surgical Respirator N95 - Possible Fake
# ..                                               ...       ...
# 2            Zimi 7711 w/ Earloops, Exhalation Valve       NaN
# 3         Zimi 7711 w/ Earloops, no Exhalation Valve       NaN
# 4            Zimi 7711 w/ Headband, Exhalation Valve       NaN
# 5         Zimi 7711 w/ Headband, no Exhalation Valve       NaN
# 60   Zovator (Harley) N95 Mask NIOSH N95 TC-84A-6973
#
#      filtration_efficiency_percent  breathability_pascals width_mm height_mm  \
# 129                          96.91                 199.07     None      None
# 536                          99.98                 138.10     None      None
# ...

# %% [markdown]
# # Filter only for those with where_to_buy_url_1

# %%
has_where_to_buy_url = armbrust_mask_nerd_pmm[
    armbrust_mask_nerd_pmm['where_to_buy_url_1'].notna()
]

has_where_to_buy_url
# Out:
#                           unique_internal_model_code age_range  \
# 11                                          3M 1860s       NaN
# 415                  3M 9205+ Aura - User Submission
# 1                     3M 9205+ Aura: User Submission
# 102         3M Aura Particulate Respirator 9205+ N95
# 24                                   4CAir Kids Mask      8-12
# ..                                               ...       ...
# 2            Zimi 7711 w/ Earloops, Exhalation Valve       NaN
# 3         Zimi 7711 w/ Earloops, no Exhalation Valve       NaN
# 4            Zimi 7711 w/ Headband, Exhalation Valve       NaN
# 5         Zimi 7711 w/ Headband, no Exhalation Valve       NaN
# 60   Zovator (Harley) N95 Mask NIOSH N95 TC-84A-6973
#
#      filtration_efficiency_percent  breathability_pascals width_mm height_mm  \
# 11                             NaN                    NaN      NaN       NaN
# 415                         100.00                 242.44     None      None
# ...

# %% [markdown]
# ## Assumption: If filtration efficiency and breathability are the same for another row (measured in 4 decimal points), they are most likely for the same mask.

# %%
with_fe_breathability_data = has_where_to_buy_url[
    has_where_to_buy_url['filtration_efficiency_percent'].notna() \
    & has_where_to_buy_url['breathability_pascals'].notna()
].drop_duplicates(subset=['filtration_efficiency_percent', 'breathability_pascals'])

with_fe_breathability_data
# Out:
#                           unique_internal_model_code age_range  \
# 415                  3M 9205+ Aura - User Submission
# 102         3M Aura Particulate Respirator 9205+ N95
# 24                                   4CAir Kids Mask      8-12
# 104                      ACI Surgical N95 Respirator
# 22                     Aegle N95 Foldable Respirator
# ..                                               ...       ...
# 33             WWDOLL KN95 Foldable Protective Masks
# 428                        Yongjie - KN95 Face Masks
# 18                       Yuikio KN95 Protective Mask
# 82                            Zerobay KF94 Face Mask
# 60   Zovator (Harley) N95 Mask NIOSH N95 TC-84A-6973
#
#      filtration_efficiency_percent  breathability_pascals width_mm height_mm  \
# 415                         100.00                 242.44     None      None
# 102                          99.86                 123.00     None      None
# ...

# %%
without_fe_breathability_data = has_where_to_buy_url[
    has_where_to_buy_url['filtration_efficiency_percent'].isna() \
    & has_where_to_buy_url['breathability_pascals'].isna()
]

without_fe_breathability_data
# Out:
#                     unique_internal_model_code age_range  \
# 11                                    3M 1860s       NaN
# 6                          Canada Masq Q100 XS       NaN
# 15                        Champak PC520 Medium       NaN
# 12             Halyard Fluidshield 46827 Small       NaN
# 13                                  Q100 Small       NaN
# 0                     Savewo 3D Meow 2-6 years       2-6
# 1                    Savewo 3D Meow 7-13 years      7-13
# 10              Shawmut Protex SR9520S - Small       NaN
# 14                                   Trident S       NaN
# 7                                   Trident XS       NaN
# 9                       Vogmask Organic Medium       NaN
# 8                                Vogmask Small       NaN
# 2      Zimi 7711 w/ Earloops, Exhalation Valve       NaN
# 3   Zimi 7711 w/ Earloops, no Exhalation Valve       NaN
# 4      Zimi 7711 w/ Headband, Exhalation Valve       NaN
# ...

# %%
no_dup_fe_breathability = with_fe_breathability_data.drop_duplicates(subset=['filtration_efficiency_percent', 'breathability_pascals'])
no_dup_fe_breathability
# Out:
#                           unique_internal_model_code age_range  \
# 415                  3M 9205+ Aura - User Submission
# 102         3M Aura Particulate Respirator 9205+ N95
# 24                                   4CAir Kids Mask      8-12
# 104                      ACI Surgical N95 Respirator
# 22                     Aegle N95 Foldable Respirator
# ..                                               ...       ...
# 33             WWDOLL KN95 Foldable Protective Masks
# 428                        Yongjie - KN95 Face Masks
# 18                       Yuikio KN95 Protective Mask
# 82                            Zerobay KF94 Face Mask
# 60   Zovator (Harley) N95 Mask NIOSH N95 TC-84A-6973
#
#      filtration_efficiency_percent  breathability_pascals width_mm height_mm  \
# 415                         100.00                 242.44     None      None
# 102                          99.86                 123.00     None      None
# ...

# %%
pd.set_option('display.max_rows', 200)

# %%
no_dup_fe_breathability.dtypes
# Out:
# unique_internal_model_code        object
# age_range                         object
# filtration_efficiency_percent    float64
# breathability_pascals            float64
# width_mm                          object
# height_mm                         object
# filter_type                       object
# style                             object
# strap_type                        object
# color                             object
# where_to_buy_url_1                object
# where_to_buy_url_2                object
# where_to_buy_url_3                object
# image_url                         object
# filtration_efficiency_source      object
# filtration_efficiency_notes       object
# breathability_pascals_source      object
# breathability_pascals_notes       object
# uimc_lower                        object
# breatheability_pascals_source     object
# breatheability_pascals_notes      object
# dtype: object

# %% [markdown]
# # Amanda Respirator Repository
#
# [Repo](https://docs.google.com/spreadsheets/d/1NuYVJasqD08cqrROVwoL9COoYtCHrLRYXShg4MtTHe4/edit?gid=0#gid=0).

# %%
amanda_elastos = pd.read_csv('./data/amanda-respirators-2024-08-07.csv', header=[3]).rename(
    columns={
        'Website': 'where_to_buy_url_1',
        '~$ cost': 'initial_cost_us_dollars',
        'Weight': 'mass_grams',
    }
)

# %%
amanda_elastos.columns
# Out:
# Index(['Name', 'Brand', 'Size name', 'Nose', 'Coverage', 'Width Min',
#        'Unnamed: 6', 'Width Max', 'Unnamed: 8',
#        '*Ratio, special. "Wideness" measurement', 'Nose-Chin Min',
#        'Unnamed: 11', 'Nose-Chin Max', 'Unnamed: 13', 'Depth', 'Depth.1',
#        'P100', 'N95', 'KN95', 'Other', 'Facepiece Material',
#        'where_to_buy_url_1', 'Latex?', 'initial_cost_us_dollars', 'mass_grams',
#        'Notes', 'Source', 'Scan'],
#       dtype='object')

# %%
amanda_elastos['unique_internal_model_code'] = amanda_elastos['Brand'] + ' ' \
    + amanda_elastos['Name'] + ' ' + amanda_elastos['Size name'] + ' for ' + amanda_elastos['Nose'] \
    + ' nose'

# %% [markdown]
# ## Standardize dimensions into millimeters

# %%
amanda_elastos['width_mm'] = amanda_elastos['Width Max'] * 25.4
amanda_elastos['height_mm'] = amanda_elastos['Nose-Chin Max'] * 25.4
amanda_elastos['depth_mm'] = amanda_elastos['Depth'] * 25.4

# %% [markdown]
# ## Add strap_type

# %%
amanda_elastos['strap_type'] = 'Headstrap'

# %% [markdown]
# ## Add style

# %%
amanda_elastos['style'] = 'Elastomeric'

# %% [markdown]
# ## Add images

# %%
collection = []
for i, row in amanda_elastos.iterrows():
    collection.append({
        'unique_internal_model_code': row['unique_internal_model_code'],
        'image_url': ''
    })

# %%
collection
# Out:
# [{'unique_internal_model_code': '3M 6100 Small for Med/Low nose',
#   'image_url': ''},
#  {'unique_internal_model_code': '3M 6200 Medium for Med/Low nose',
#   'image_url': ''},
#  {'unique_internal_model_code': '3M 6300 Large for Med/Low nose',
#   'image_url': ''},
#  {'unique_internal_model_code': '3M 6501 Small for Med/High nose',
#   'image_url': ''},
#  {'unique_internal_model_code': '3M 6502 Medium for Med/High nose',
#   'image_url': ''},
#  {'unique_internal_model_code': '3M 6503 Large for Med/High nose',
#   'image_url': ''},
#  {'unique_internal_model_code': '3M 7501 Small for Med/High nose',
#   'image_url': ''},
#  {'unique_internal_model_code': '3M 7502 Medium for Med/High nose',
#   'image_url': ''},
#  {'unique_internal_model_code': '3M 7503 Large for High nose',
#   'image_url': ''},
#  {'unique_internal_model_code': '3M 6200DD Medium for Med/High nose',
#   'image_url': ''},
#  {'unique_internal_model_code': '3M Secure-Click Small for Med/High nose',
# ...

# %%
amanda_images = [
    {'unique_internal_model_code': '3M 6100 Small for Med/Low nose',
  'image_url': 'https://static.wixstatic.com/media/090778_5209ed65b8bf4e0ba73c92194368329c~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_5209ed65b8bf4e0ba73c92194368329c~mv2.jpg'},
 {'unique_internal_model_code': '3M 6200 Medium for Med/Low nose',
  'image_url': 'https://static.wixstatic.com/media/090778_e0d2c9c5d7bc47b7b07eb7774dd3a623~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_e0d2c9c5d7bc47b7b07eb7774dd3a623~mv2.jpg'},
 {'unique_internal_model_code': '3M 6300 Large for Med/Low nose',
  'image_url': 'https://static.wixstatic.com/media/090778_76db4335679c442780f9b04dd8efd6a9~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_76db4335679c442780f9b04dd8efd6a9~mv2.jpg'},
 {'unique_internal_model_code': '3M 6501 Small for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_f066224ffccc4ff0ab207ebb166f8fb2~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_f066224ffccc4ff0ab207ebb166f8fb2~mv2.jpg'},
 {'unique_internal_model_code': '3M 6502 Medium for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_e53ea0b1d7124cc381fc16121a95a141~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_e53ea0b1d7124cc381fc16121a95a141~mv2.jpg'},
 {'unique_internal_model_code': '3M 6503 Large for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_1b874d78b5214c97983d01cb22d26368~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_1b874d78b5214c97983d01cb22d26368~mv2.jpg'},
 {'unique_internal_model_code': '3M 7501 Small for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_146c5b14d11c47e1ace73acbdf4bc286~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_146c5b14d11c47e1ace73acbdf4bc286~mv2.jpg'},
 {'unique_internal_model_code': '3M 7502 Medium for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_e61f33e236574918ad46fd0b52444c0f~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_e61f33e236574918ad46fd0b52444c0f~mv2.jpg'},
 {'unique_internal_model_code': '3M 7503 Large for High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_7bbc1bcb937e466ba4aec34e539bcd6d~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_7bbc1bcb937e466ba4aec34e539bcd6d~mv2.jpg'},
 {'unique_internal_model_code': '3M 6200DD Medium for Med/High nose',
  'image_url': ''},
 {'unique_internal_model_code': '3M Secure-Click Small for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_ad17473c06c845e4aa8dc442c9bc4b06~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_ad17473c06c845e4aa8dc442c9bc4b06~mv2.jpg'},
 {'unique_internal_model_code': '3M Secure-Click Medium for High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_512738a101904edbadcc2c46d84b2f5d~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_512738a101904edbadcc2c46d84b2f5d~mv2.jpg'},
 {'unique_internal_model_code': '3M Secure-Click Large for High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_95af82e7fb274a8c91ec6c9df6a14e05~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_95af82e7fb274a8c91ec6c9df6a14e05~mv2.jpg'},
 {'unique_internal_model_code': 'AirBoss AirBoss L/XL for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_52e10ea8b31244848fb0dae26c336476~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_52e10ea8b31244848fb0dae26c336476~mv2.jpg'},
 {'unique_internal_model_code': 'AirBoss AirBoss S/M for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_ba05c2e1330c4c8b9fa3ccead0c05a32~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_ba05c2e1330c4c8b9fa3ccead0c05a32~mv2.jpg'},
 {'unique_internal_model_code': 'Armbrust Breathe99 One Size for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_6e1dea23870240beb54b0600950dafc4~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_6e1dea23870240beb54b0600950dafc4~mv2.jpg'},
 {'unique_internal_model_code': 'AYYBF M601  Medium for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_5e4ddc4d04ef4413a32a2296cdfc7b2d~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_5e4ddc4d04ef4413a32a2296cdfc7b2d~mv2.jpg'},
 {'unique_internal_model_code': 'BAOMAO US-SW-10 One Size for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_6728e6b07fe7439c8d2c5a6532cb497c~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_6728e6b07fe7439c8d2c5a6532cb497c~mv2.jpg'},
 {'unique_internal_model_code': 'CNSTRONG Clear One Size for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_97aee94d51a647a2b6c98a32fac499d6~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_97aee94d51a647a2b6c98a32fac499d6~mv2.jpg'},
 {'unique_internal_model_code': 'Dentec ComfortAir S/M for Med/High nose',
  'image_url': ''},
 {'unique_internal_model_code': 'Dentec ComfortAir Medium for High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_daef924f6c4345148c982150268a08b9~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_daef924f6c4345148c982150268a08b9~mv2.jpg'},
 {'unique_internal_model_code': 'Dentec Comfortair M/L for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_1859b88f01074f4ba4acade0129f1d25~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_1859b88f01074f4ba4acade0129f1d25~mv2.jpg'},
 {'unique_internal_model_code': 'Dentec Comfortair NX M/L for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_31b27680cff74a61a065166b93b8f145~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_31b27680cff74a61a065166b93b8f145~mv2.jpg'},
 {'unique_internal_model_code': 'Drager 3500 Small for High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_7985471bce0047b49488c4a70e5d64ea~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_7985471bce0047b49488c4a70e5d64ea~mv2.jpg'},
 {'unique_internal_model_code': 'Drager 3500 Medium for High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_8ce85577038a41b9bf1982b1e190dee6~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_8ce85577038a41b9bf1982b1e190dee6~mv2.jpg'},
 {'unique_internal_model_code': 'Drager 3500 Large for High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_9204f5c3c18a4f31929f1c6c28a487bf~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_9204f5c3c18a4f31929f1c6c28a487bf~mv2.jpg'},
 {'unique_internal_model_code': 'Elastomask Pro Elastomask Pro Small for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_becd26b458164b0289b7836ed6b6a4bf~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_becd26b458164b0289b7836ed6b6a4bf~mv2.jpg'},
 {'unique_internal_model_code': 'Elastomask Pro Elastomask Pro Medium/Large for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_2da33a6de6554c58b6f21f7751af74ef~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_2da33a6de6554c58b6f21f7751af74ef~mv2.jpg'},
 {'unique_internal_model_code': 'Envo Envo Classic One Size for Med/Low nose',
  'image_url': 'https://static.wixstatic.com/media/090778_e03f3747979e48be987a7abab49f5d23~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_e03f3747979e48be987a7abab49f5d23~mv2.jpg'},
 {'unique_internal_model_code': 'Envo Envo Pro XL for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_38b8762f3a9a40a28e1fe18a9bf038bb~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_38b8762f3a9a40a28e1fe18a9bf038bb~mv2.jpg'},
 {'unique_internal_model_code': 'Envo Envo Pro Regular for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_aefd7836a6cd4a8681b85e9f1187b66a~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_aefd7836a6cd4a8681b85e9f1187b66a~mv2.jpg'},
 {'unique_internal_model_code': 'Flo Flo Kids One Size for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_40a3117973c64bf6b79252a3fd61c2d0~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_40a3117973c64bf6b79252a3fd61c2d0~mv2.jpg'},
 {'unique_internal_model_code': 'Flo Flo Pro Med/High for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_a639bcabf58d412385ba444fd59393a0~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_a639bcabf58d412385ba444fd59393a0~mv2.jpg'},
 {'unique_internal_model_code': 'Flo Flo Pro Low/Med for Low nose',
  'image_url': 'https://static.wixstatic.com/media/090778_dca6d5076d1b44ef9f43e5b8a33e0459~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_dca6d5076d1b44ef9f43e5b8a33e0459~mv2.jpg'},
 {'unique_internal_model_code': 'Gill Gill Small/Junior for Med/Low nose',
  'image_url': 'https://static.wixstatic.com/media/090778_f46c692b06e343cd96cc55c4c31ba151~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_f46c692b06e343cd96cc55c4c31ba151~mv2.jpg'},
 {'unique_internal_model_code': 'Gill Gill Pro Regular for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_e2550db8a5f748339945a3939fed76f5~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_e2550db8a5f748339945a3939fed76f5~mv2.jpg'},
 {'unique_internal_model_code': 'Gill Gill/Gill Pro Large for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_4bb87e8535b74f608fc17888735a4187~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_4bb87e8535b74f608fc17888735a4187~mv2.jpg'},
 {'unique_internal_model_code': 'GVS Elipse S/M for High nose',
  'image_url': ''},
 {'unique_internal_model_code': 'GVS Elipse M/L for High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_8df6964908e84f6299ac36dd06017114~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_8df6964908e84f6299ac36dd06017114~mv2.jpg'},
 {'unique_internal_model_code': 'GVS Elipse Integra S/M for High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_a926999be5474da0890c08e957b1992d~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_a926999be5474da0890c08e957b1992d~mv2.jpg'},
 {'unique_internal_model_code': 'GVS Elipse Integra M/L for High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_12cd707b575b4b0b93d98c62ffe9b92e~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_12cd707b575b4b0b93d98c62ffe9b92e~mv2.jpg'},
 {'unique_internal_model_code': 'Honeywell 5500 Medium for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_fc5296a7dfca439486b21dff455675a9~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_fc5296a7dfca439486b21dff455675a9~mv2.jpg'},
 {'unique_internal_model_code': 'Honeywell 7700 Small for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_1a052ec06c1a47f2aad800a84fe6788a~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_1a052ec06c1a47f2aad800a84fe6788a~mv2.jpg'},
 {'unique_internal_model_code': 'Honeywell 7700 Medium for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_67aee330ec544619b65c8d458f4c05c3~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_67aee330ec544619b65c8d458f4c05c3~mv2.jpg'},
 {'unique_internal_model_code': 'Honeywell 7700 Large for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_7ccbf717d4a9487680ee543ba37f2150~mv2.jpg/v1/fill/w_500,h_500,al_c,q_85/090778_7ccbf717d4a9487680ee543ba37f2150~mv2.jpg'},
 {'unique_internal_model_code': 'Honeywell RU8800 Small for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_cfdfc7464a014037a038b98855747664~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_cfdfc7464a014037a038b98855747664~mv2.jpg'},
 {'unique_internal_model_code': 'Honeywell RU8800 Medium/Large for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_d7c99d365c42445682430ab8b1410d8b~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_d7c99d365c42445682430ab8b1410d8b~mv2.jpg'},
 {'unique_internal_model_code': 'Jingwei 6800 One Size for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_b54ec0eaa5f545e1ac94706063e0027e~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_b54ec0eaa5f545e1ac94706063e0027e~mv2.jpg'},
 {'unique_internal_model_code': 'KAMZSZMF  610 Medium for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_4ce3ca0c491042c583b8c572c64a048d~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_4ce3ca0c491042c583b8c572c64a048d~mv2.jpg'},
 {'unique_internal_model_code': 'Moldex 7000 Small for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_cce13c6047ae47aa9cb12cb6ef64f1f3~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_cce13c6047ae47aa9cb12cb6ef64f1f3~mv2.jpg'},
 {'unique_internal_model_code': 'Moldex 7000 Medium for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_9aeae57712844bacb9c5ef02c49b557c~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_9aeae57712844bacb9c5ef02c49b557c~mv2.jpg'},
 {'unique_internal_model_code': 'Moldex 7000 Large for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_3251aea1990b42c989155bcaa247f7e7~mv2.jpg/v1/fill/w_599,h_599,al_c,lg_1,q_80,enc_auto/090778_3251aea1990b42c989155bcaa247f7e7~mv2.jpg'},
 {'unique_internal_model_code': 'Moldex 8001 Small for Med/Low nose',
  'image_url': 'https://static.wixstatic.com/media/090778_39ad67687e0643039dcafcaeedad4bb0~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_39ad67687e0643039dcafcaeedad4bb0~mv2.jpg'},
 {'unique_internal_model_code': 'Moldex 8002 Medium for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_bbb2b32f7f3247b7a9bc58e7a76fb132~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_bbb2b32f7f3247b7a9bc58e7a76fb132~mv2.jpg'},
 {'unique_internal_model_code': 'MSA Advantage 290 Small for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_f0f006f13069485ebe0157a0ae95097e~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_f0f006f13069485ebe0157a0ae95097e~mv2.jpg'},
 {'unique_internal_model_code': 'MSA Advantage 290 Medium for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_d24bfb121c8e4adf8554c91df55f250f~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_d24bfb121c8e4adf8554c91df55f250f~mv2.jpg'},
 {'unique_internal_model_code': 'MSA Advantage 290 Large for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_6a7b79f30c10482f954c49e30eb8f0ff~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_6a7b79f30c10482f954c49e30eb8f0ff~mv2.jpg'},
 {'unique_internal_model_code': 'O2 Curve High for Med/High nose',
  'image_url': 'https://static.wixstatic.com/media/090778_e5b82618e5304ac687a11d6bb5b64155~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_e5b82618e5304ac687a11d6bb5b64155~mv2.jpg'},
 {'unique_internal_model_code': 'O2 Curve Low for Med/Low nose',
  'image_url': 'https://static.wixstatic.com/media/090778_d9f4d1e533ab483c95a68df50ca522c7~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_d9f4d1e533ab483c95a68df50ca522c7~mv2.jpg'},
 {'unique_internal_model_code': 'Omnimask Omnimask One Size for Med/High nose',
  'image_url': ''},
 {'unique_internal_model_code': 'Scott Xcel Small for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_1974e15dbeb544a6816e2375c08fc6e0~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_1974e15dbeb544a6816e2375c08fc6e0~mv2.jpg'},
 {'unique_internal_model_code': 'stealth Air Light One Size for High nose',
  'image_url': ''},
 {'unique_internal_model_code': 'Trend Stealth S/M for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_78852e0819c147b99b1ee1c0898f0c01~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_78852e0819c147b99b1ee1c0898f0c01~mv2.jpg'},
 {'unique_internal_model_code': 'Trend Stealth M/L for Medium nose',
  'image_url': 'https://static.wixstatic.com/media/090778_84dbe930f9dc4901bbb28a01cf264b5b~mv2.jpg/v1/fill/w_600,h_600,al_c,lg_1,q_80,enc_auto/090778_84dbe930f9dc4901bbb28a01cf264b5b~mv2.jpg'},
]

# %% [markdown]
# ### amanda_elastos_with_image_urls

# %%
amanda_elastos_with_image_urls = pd.DataFrame(amanda_images).merge(amanda_elastos, on='unique_internal_model_code')

# %%
amanda_elastos_with_image_urls_final = amanda_elastos_with_image_urls[
    ['unique_internal_model_code', 'initial_cost_us_dollars', 'strap_type', 'width_mm', 'height_mm', 'depth_mm', 'mass_grams', 'where_to_buy_url_1', 'image_url', 'style']
]

# %%
combined = pd.concat(
    [
        without_fe_breathability_data,
        with_fe_breathability_data,
        amanda_elastos_with_image_urls_final
    ]
)

# %%
combined
# Out:
#                       unique_internal_model_code age_range  \
# 11                                      3M 1860s       NaN
# 6                            Canada Masq Q100 XS       NaN
# 15                          Champak PC520 Medium       NaN
# 12               Halyard Fluidshield 46827 Small       NaN
# 13                                    Q100 Small       NaN
# ..                                           ...       ...
# 59  Omnimask Omnimask One Size for Med/High nose       NaN
# 60              Scott Xcel Small for Medium nose       NaN
# 61      stealth Air Light One Size for High nose       NaN
# 62             Trend Stealth S/M for Medium nose       NaN
# 63             Trend Stealth M/L for Medium nose       NaN
#
#     filtration_efficiency_percent  breathability_pascals width_mm height_mm  \
# 11                            NaN                    NaN      NaN       NaN
# 6                             NaN                    NaN      NaN       NaN
# ...

# %%
combined.groupby('style').count()[['unique_internal_model_code']]
# Out:
#                                               unique_internal_model_code
# style
# Bifold                                                                76
# Bifold & Gasket                                                        4
# Boat                                                                  59
# Cotton + High Filtration Efficiency Material                           2
# Cup                                                                    6
# Duckbill                                                               5
# Elastomeric                                                           64

# %% [markdown]
# # Save combined data

# %%
combined.to_csv('./data/amanda_armbrust_masknerd_pmm_for_kids_with_where_to_buy_url.csv', index=False)
